# %%
import pandas as pd

# Load dataset
df = pd.read_csv("API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv", skiprows=4)

# View top rows
print(df.head())
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130075728.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2016         2017         2018         2019  \
# ...

# %%
# Filter data for India
india = df[df['Country Name'] == 'India']
print(india)
# Out:
#     Country Name Country Code     Indicator Name Indicator Code         1960  \
# 109        India          IND  Population, total    SP.POP.TOTL  435990338.0
#
#             1961         1962         1963         1964         1965  ...  \
# 109  446564729.0  457283090.0  468138575.0  479229598.0  490140146.0  ...
#
#              2016          2017          2018          2019          2020  \
# 109  1.343944e+09  1.359657e+09  1.374659e+09  1.389030e+09  1.402618e+09
#
#              2021          2022          2023          2024  Unnamed: 69
# 109  1.414204e+09  1.425423e+09  1.438070e+09  1.450936e+09          NaN
#
# [1 rows x 70 columns]

# %%
import matplotlib.pyplot as plt

# Extract year columns
years = india.columns[4:-1]  # All years (skip metadata)
population = india.loc[:, years].values.flatten()

# Plot
plt.figure(figsize=(12,6))
plt.plot(years, population, marker='o', linestyle='-', color='royalblue')
plt.title("India's Population Growth (1960–2022)", fontsize=16)
plt.xlabel("Year")
plt.ylabel("Population")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
selected_years = ['1960', '1980', '2000', '2020', '2022']
selected_pop = india[selected_years].values.flatten()

plt.bar(selected_years, selected_pop, color='skyblue')
plt.title("India's Population at Selected Years")
plt.xlabel("Year")
plt.ylabel("Population")
plt.show()
